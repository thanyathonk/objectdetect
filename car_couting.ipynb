# %%
from ultralytics import YOLO
import cv2
import cvzone
import math

# %%
model = YOLO("yolo_weight/yolov8n.pt")
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]
cap = cv2.VideoCapture(0)
cap.set(3, 1280)
cap.set(4, 720)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    success, img = cap.read()
    if not success or img is None:
        print("Error: Failed to read frame.")
        break
    result = model(img, stream=True)
    for r in result:
        boxes = r.boxes
        for box in boxes:
            cls = int(box.cls[0])
            if classNames[cls] == 'person':
                # Bounding
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                w, h = x2 - x1, y2 - y1
                cvzone.cornerRect(img, (x1, y1, w, h))

                conf = math.ceil((box.conf[0] * 100)) / 100
                
                
                cvzone.putTextRect(img, f'{classNames[cls]} {conf}', (max(0, x1), max(35, y1)), scale=1, thickness=1)

    cv2.imshow("Image", img)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 4 persons, 1 chair, 3 tvs, 51.0ms
# Speed: 11.9ms preprocess, 51.0ms inference, 24.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bottle, 1 chair, 3 tvs, 61.2ms
# Speed: 4.4ms preprocess, 61.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bottle, 1 chair, 4 tvs, 1 laptop, 63.1ms
# Speed: 1.8ms preprocess, 63.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 64.5ms
# Speed: 2.8ms preprocess, 64.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 64.6ms
# Speed: 1.9ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 4 tvs, 1 laptop, 64.8ms
# Speed: 2.8ms preprocess, 64.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 4 tvs, 1 laptop, 61.7ms
# Speed: 2.8ms preprocess, 61.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 4 tvs, 1 laptop, 61.5ms
# Speed: 2.1ms preprocess, 61.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 4 tvs, 1 laptop, 65.8ms
# Speed: 1.4ms preprocess, 65.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 63.9ms
# Speed: 2.0ms preprocess, 63.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 68.1ms
# Speed: 2.5ms preprocess, 68.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 67.2ms
# Speed: 1.5ms preprocess, 67.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 64.6ms
# Speed: 1.5ms preprocess, 64.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 63.3ms
# Speed: 2.1ms preprocess, 63.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 66.5ms
# Speed: 2.0ms preprocess, 66.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 61.0ms
# Speed: 2.8ms preprocess, 61.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 4 tvs, 1 laptop, 63.6ms
# Speed: 2.3ms preprocess, 63.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 4 tvs, 1 laptop, 67.0ms
# Speed: 2.9ms preprocess, 67.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 67.4ms
# Speed: 2.9ms preprocess, 67.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 4 tvs, 1 laptop, 64.5ms
# Speed: 2.3ms preprocess, 64.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 4 tvs, 1 laptop, 65.7ms
# Speed: 1.5ms preprocess, 65.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 4 tvs, 1 laptop, 67.5ms
# Speed: 3.4ms preprocess, 67.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 4 tvs, 1 laptop, 63.3ms
# Speed: 1.3ms preprocess, 63.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 4 tvs, 1 laptop, 54.8ms
# Speed: 1.8ms preprocess, 54.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 37.2ms
# Speed: 1.7ms preprocess, 37.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 40.4ms
# Speed: 1.3ms preprocess, 40.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 63.7ms
# Speed: 1.7ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 44.3ms
# Speed: 1.5ms preprocess, 44.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 36.6ms
# Speed: 1.6ms preprocess, 36.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 37.7ms
# Speed: 1.4ms preprocess, 37.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 37.1ms
# Speed: 1.2ms preprocess, 37.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 38.3ms
# Speed: 1.5ms preprocess, 38.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 35.3ms
# Speed: 1.4ms preprocess, 35.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 37.0ms
# Speed: 1.4ms preprocess, 37.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 37.0ms
# Speed: 1.8ms preprocess, 37.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 37.0ms
# Speed: 1.6ms preprocess, 37.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 35.1ms
# Speed: 1.5ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 38.7ms
# Speed: 1.6ms preprocess, 38.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 38.0ms
# Speed: 1.4ms preprocess, 38.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 35.7ms
# Speed: 1.8ms preprocess, 35.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 37.0ms
# Speed: 1.4ms preprocess, 37.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 38.1ms
# Speed: 1.7ms preprocess, 38.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 38.6ms
# Speed: 1.4ms preprocess, 38.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 38.4ms
# Speed: 1.4ms preprocess, 38.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 39.4ms
# Speed: 1.7ms preprocess, 39.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 37.2ms
# Speed: 1.5ms preprocess, 37.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 37.9ms
# Speed: 1.5ms preprocess, 37.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 36.7ms
# Speed: 1.4ms preprocess, 36.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 54.0ms
# Speed: 1.7ms preprocess, 54.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 37.0ms
# Speed: 1.5ms preprocess, 37.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 37.5ms
# Speed: 1.4ms preprocess, 37.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 56.6ms
# Speed: 4.5ms preprocess, 56.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 43.9ms
# Speed: 1.8ms preprocess, 43.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 4 tvs, 1 laptop, 37.6ms
# Speed: 1.4ms preprocess, 37.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 36.8ms
# Speed: 1.7ms preprocess, 36.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 4 tvs, 1 laptop, 36.5ms
# Speed: 1.4ms preprocess, 36.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 4 tvs, 1 laptop, 39.3ms
# Speed: 1.6ms preprocess, 39.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 4 tvs, 1 laptop, 36.9ms
# Speed: 1.5ms preprocess, 36.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 36.8ms
# Speed: 1.4ms preprocess, 36.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 4 tvs, 1 laptop, 37.6ms
# Speed: 1.9ms preprocess, 37.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 37.5ms
# Speed: 1.6ms preprocess, 37.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 4 tvs, 1 laptop, 37.9ms
# Speed: 1.5ms preprocess, 37.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 4 tvs, 1 laptop, 39.6ms
# Speed: 1.8ms preprocess, 39.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 36.3ms
# Speed: 1.3ms preprocess, 36.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 37.5ms
# Speed: 1.2ms preprocess, 37.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 36.2ms
# Speed: 1.4ms preprocess, 36.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 46.3ms
# Speed: 1.6ms preprocess, 46.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 54.5ms
# Speed: 2.6ms preprocess, 54.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 43.4ms
# Speed: 1.7ms preprocess, 43.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 43.9ms
# Speed: 1.6ms preprocess, 43.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 45.1ms
# Speed: 1.6ms preprocess, 45.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 38.4ms
# Speed: 1.6ms preprocess, 38.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 36.8ms
# Speed: 2.3ms preprocess, 36.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 35.0ms
# Speed: 1.5ms preprocess, 35.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 34.6ms
# Speed: 1.4ms preprocess, 34.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 34.4ms
# Speed: 1.7ms preprocess, 34.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 35.9ms
# Speed: 1.5ms preprocess, 35.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 35.4ms
# Speed: 1.4ms preprocess, 35.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 4 tvs, 1 laptop, 36.5ms
# Speed: 1.5ms preprocess, 36.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 34.1ms
# Speed: 1.6ms preprocess, 34.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 4 tvs, 1 laptop, 36.6ms
# Speed: 1.7ms preprocess, 36.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 4 tvs, 1 laptop, 34.5ms
# Speed: 1.6ms preprocess, 34.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 4 tvs, 1 laptop, 32.7ms
# Speed: 1.6ms preprocess, 32.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 4 tvs, 1 laptop, 33.2ms
# Speed: 1.2ms preprocess, 33.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 35.4ms
# Speed: 1.5ms preprocess, 35.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 34.2ms
# Speed: 1.5ms preprocess, 34.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 33.8ms
# Speed: 1.2ms preprocess, 33.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 34.5ms
# Speed: 1.5ms preprocess, 34.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 35.1ms
# Speed: 1.7ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 3 tvs, 1 laptop, 34.8ms
# Speed: 1.1ms preprocess, 34.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 3 tvs, 1 laptop, 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
